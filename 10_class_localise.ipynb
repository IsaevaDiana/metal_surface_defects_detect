# %%
import os
import glob
labels_path = glob.glob('/kaggle/input/label/label/*.xml')
len(labels_path)
# Out:
# 2280

# %%
images_path_all = glob.glob('/kaggle/input/images/images/*/*.jpg')
len(images_path_all)
# Out:
# 2306

# %%
from pathlib import Path
l_path = Path('/kaggle/input/label/label')
i_path = Path('/kaggle/input/images/images')
images_path = []
for img in i_path.rglob("*.jpg"):
    for label in l_path.glob("*.xml"):
        #print(img.stem, label.stem)
        if img.stem == label.stem:
            images_path.append(img)
len(images_path)
# Out:
# 2280

# %%
from collections import Counter
counter = Counter([os.path.basename(x) for x in images_path])
duplicates = [x.split(".")[0] for x,y in counter.items() if y > 1]
duplicates
# Out:
# []

# %%
source_folder = Path('/kaggle/working/for_data/')
source_folder.mkdir(parents=True, exist_ok=True)

# %%
import xml.etree.ElementTree as ET
import glob
import re
import torch

for label in l_path.glob("*.xml"):
    tree = ET.parse(label)
    #ET.dump(tree)
    root = tree.getroot()
    normalized_info = ''
    for object_element in root.findall(".//object"):
    
        bndbox_element = object_element.find("bndbox")

        xmin = int(bndbox_element.find("xmin").text)
        ymin = int(bndbox_element.find("ymin").text)
        xmax = int(bndbox_element.find("xmax").text)
        ymax = int(bndbox_element.find("ymax").text)

        width = (xmax - xmin)/2048
        height = (ymax - ymin)/1000

        xc = xmin/2048 + width/2
        yc = ymin/1000 + height/2

        name_element = object_element.find("name")
        
        match = re.search(r'\d+', name_element.text)
        if match:
            num_class = int(match.group()) - 1
            #num_class = int(match.group())
            #print(num_class)
            
            file_name = label.stem
            #print(file_name)
            normalized_info += str(num_class) + ' ' + str(xc) + ' ' + str(yc) + ' ' + str(width) + ' ' + str(height) + '\n'
#             with open(os.path.join('/kaggle/working/for_data', f'{file_name}.txt'), 'a') as file:
#                 # Запись в файл
#                 file.write(f'{num_class} {xc} {yc} {width} {height}\n')
#                 #print(f'{num_class} {xc} {yc} {width} {height}\n')
        else:
            print("No digits found in name_element.text")
            print(label)
        p = source_folder / Path(label.stem + '.txt')
        p.write_text(normalized_info)
# Out:
# No digits found in name_element.text
# /kaggle/input/label/label/img_02_425616500_00770.xml

# %%
cd /kaggle/working/for_data
# Out:
# /kaggle/working/for_data

# %%
ls | wc -l
# Out:
# 2280

# %%
cat img_02_425616500_00770.txt
# Out:
# 1 0.500732421875 0.1185 0.99853515625 0.071

# %%
import random
from shutil import copyfile

train_folder = "/kaggle/working/train"
test_folder = "/kaggle/working/test"
valid_folder = "/kaggle/working/valid"

for folder in [train_folder, test_folder, valid_folder]:
    os.makedirs(folder, exist_ok=True)

# %%
from typing import Union

img_source_path = Path('/kaggle/input/images/images')

def get_jpg_and_txt_files(img_source_path):
    txt_files, jpg_files = [], []
    #print(next(source_folder.glob("*.txt")), next(l_path.glob("*.xml")))
    for label in l_path.glob("*.xml"):
        for img in img_source_path.glob("*.jpg"):
            if img.stem == label.stem:
                jpg_files.append(img)
                txt_files.append(source_folder / Path(label.stem + '.txt'))
    return jpg_files, txt_files

jpg_files_crease, txt_files_crease = get_jpg_and_txt_files(i_path / Path('crease'))
print(len(jpg_files_crease), len(txt_files_crease))
jpg_files_crescent_gap ,txt_files_crescent_gap = get_jpg_and_txt_files(i_path / Path('crescent_gap'))
print(len(jpg_files_crescent_gap), len(txt_files_crescent_gap))
jpg_files_inclusion ,txt_files_inclusion = get_jpg_and_txt_files(i_path / Path('inclusion'))
print(len(jpg_files_inclusion), len(txt_files_inclusion))
jpg_files_oil_spot ,txt_files_oil_spot = get_jpg_and_txt_files(i_path / Path('oil_spot'))
print(len(jpg_files_oil_spot), len(txt_files_oil_spot))
jpg_files_punching_hole ,txt_files_punching_hole = get_jpg_and_txt_files(i_path / Path('punching_hole'))
print(len(jpg_files_punching_hole), len(txt_files_punching_hole))
jpg_files_rolled_pit ,txt_files_rolled_pit = get_jpg_and_txt_files(i_path / Path('rolled_pit'))
print(len(jpg_files_rolled_pit), len(txt_files_rolled_pit))
jpg_files_silk_spot ,txt_files_silk_spot = get_jpg_and_txt_files(i_path / Path('silk_spot'))
print(len(jpg_files_silk_spot), len(txt_files_silk_spot))
jpg_files_waist_folding ,txt_files_waist_folding = get_jpg_and_txt_files(i_path / Path('waist folding'))
print(len(jpg_files_waist_folding), len(txt_files_waist_folding))
jpg_files_water_spot ,txt_files_water_spot = get_jpg_and_txt_files(i_path / Path('water_spot'))
print(len(jpg_files_water_spot), len(txt_files_water_spot))
jpg_files_welding_line ,txt_files_welding_line = get_jpg_and_txt_files(i_path / Path('welding_line'))
print(len(jpg_files_welding_line), len(txt_files_welding_line))
# Out:
# 51 51
# 224 224
# 211 211
# 204 204
# 215 215
# 28 28
# 649 649
# 144 144
# 287 287
# 267 267

# %%
txt_files_crease = sorted(txt_files_crease, key=lambda x: x.stem)
jpg_files_crease = sorted(jpg_files_crease, key=lambda x: x.stem)

for txt, jpg in zip(txt_files_crease, jpg_files_crease):
    assert txt.stem == jpg.stem, f"{txt.stem}, {txt.stem}"
    
txt_files_crescent_gap = sorted(txt_files_crescent_gap, key=lambda x: x.stem)
jpg_files_crescent_gap = sorted(jpg_files_crescent_gap, key=lambda x: x.stem)

for txt, jpg in zip(txt_files_crescent_gap, jpg_files_crescent_gap):
    assert txt.stem == jpg.stem

txt_files_inclusion = sorted(txt_files_inclusion, key=lambda x: x.stem)
jpg_files_inclusion = sorted(jpg_files_inclusion, key=lambda x: x.stem)

for txt, jpg in zip(txt_files_inclusion, jpg_files_inclusion):
    assert txt.stem == jpg.stem
    
txt_files_oil_spot = sorted(txt_files_oil_spot, key=lambda x: x.stem)
jpg_files_oil_spot = sorted(jpg_files_oil_spot, key=lambda x: x.stem)

for txt, jpg in zip(txt_files_oil_spot, jpg_files_oil_spot):
    assert txt.stem == jpg.stem
    
txt_files_punching_hole = sorted(txt_files_punching_hole, key=lambda x: x.stem)
jpg_files_punching_hole = sorted(jpg_files_punching_hole, key=lambda x: x.stem)

for txt, jpg in zip(txt_files_punching_hole, jpg_files_punching_hole):
    assert txt.stem == jpg.stem
    
txt_files_rolled_pit = sorted(txt_files_rolled_pit, key=lambda x: x.stem)
jpg_files_rolled_pit = sorted(jpg_files_rolled_pit, key=lambda x: x.stem)

for txt, jpg in zip(txt_files_rolled_pit, jpg_files_rolled_pit):
    assert txt.stem == jpg.stem
    
txt_files_silk_spot = sorted(txt_files_silk_spot, key=lambda x: x.stem)
jpg_files_silk_spot = sorted(jpg_files_silk_spot, key=lambda x: x.stem)

for txt, jpg in zip(txt_files_silk_spot, jpg_files_silk_spot):
    assert txt.stem == jpg.stem
    
txt_files_waist_folding = sorted(txt_files_waist_folding, key=lambda x: x.stem)
jpg_files_waist_folding = sorted(jpg_files_waist_folding, key=lambda x: x.stem)

for txt, jpg in zip(txt_files_waist_folding, jpg_files_waist_folding):
    assert txt.stem == jpg.stem
    
txt_files_water_spot = sorted(txt_files_water_spot, key=lambda x: x.stem)
jpg_files_water_spot = sorted(jpg_files_water_spot, key=lambda x: x.stem)

for txt, jpg in zip(txt_files_water_spot, jpg_files_water_spot):
    assert txt.stem == jpg.stem
    
txt_files_welding_line = sorted(txt_files_welding_line, key=lambda x: x.stem)
jpg_files_welding_line = sorted(jpg_files_welding_line, key=lambda x: x.stem)

for txt, jpg in zip(txt_files_welding_line, jpg_files_welding_line):
    assert txt.stem == jpg.stem

# %%
def split_indexes(indexes):
    total_files = len(indexes)
    train_count = int(total_files * 0.7)
    test_count = int(total_files * 0.15)
    train_indexes = indexes[:train_count]
    #print(train_indexes)
    test_indexes = indexes[train_count: train_count + test_count]
    
    val_indexes = indexes[(train_count + test_count):]
    return train_indexes, test_indexes, val_indexes

def data_from_index(indexes, data):
    data_list = []
    for i in indexes:
        data_list.append(data[i])
    return data_list

# %%
indexes_crease = list(range(len(txt_files_crease)))
#print(len(txt_files_crease))
random.shuffle(indexes_crease)

train_files_crease_i, test_files_crease_i, val_files_crease_i = split_indexes(indexes_crease)

train_files_crease = data_from_index(train_files_crease_i, txt_files_crease) + data_from_index(train_files_crease_i, jpg_files_crease)
test_files_crease = data_from_index(test_files_crease_i, txt_files_crease) + data_from_index(test_files_crease_i, jpg_files_crease)
val_files_crease = data_from_index(val_files_crease_i, txt_files_crease) + data_from_index(val_files_crease_i, jpg_files_crease)
len(train_files_crease), len(test_files_crease), len(val_files_crease)
# Out:
# (70, 14, 18)

# %%
indexes_crescent_gap = list(range(len(txt_files_crescent_gap)))

random.shuffle(indexes_crescent_gap)

train_files_crescent_gap_i, test_files_crescent_gap_i, val_files_crescent_gap_i = split_indexes(indexes_crescent_gap)

train_files_crescent_gap = data_from_index(train_files_crescent_gap_i, txt_files_crescent_gap) + data_from_index(train_files_crescent_gap_i, jpg_files_crescent_gap)
test_files_crescent_gap = data_from_index(test_files_crescent_gap_i, txt_files_crescent_gap) + data_from_index(test_files_crescent_gap_i, jpg_files_crescent_gap)
val_files_crescent_gap = data_from_index(val_files_crescent_gap_i, txt_files_crescent_gap) + data_from_index(val_files_crescent_gap_i, jpg_files_crescent_gap)
len(train_files_crescent_gap), len(test_files_crescent_gap), len(val_files_crescent_gap)
# Out:
# (312, 66, 70)

# %%
indexes_inclusion = list(range(len(txt_files_inclusion)))

random.shuffle(indexes_inclusion)

train_files_inclusion_i, test_files_inclusion_i, val_files_inclusion_i = split_indexes(indexes_inclusion)

train_files_inclusion = data_from_index(train_files_inclusion_i, txt_files_inclusion) + data_from_index(train_files_inclusion_i, jpg_files_inclusion)
test_files_inclusion = data_from_index(test_files_inclusion_i, txt_files_inclusion) + data_from_index(test_files_inclusion_i, jpg_files_inclusion)
val_files_inclusion = data_from_index(val_files_inclusion_i, txt_files_inclusion) + data_from_index(val_files_inclusion_i, jpg_files_inclusion)
len(train_files_inclusion), len(test_files_inclusion), len(val_files_inclusion)
# Out:
# (294, 62, 66)

# %%
indexes_oil_spot = list(range(len(txt_files_oil_spot)))

random.shuffle(indexes_oil_spot)

train_files_oil_spot_i, test_files_oil_spot_i, val_files_oil_spot_i = split_indexes(indexes_oil_spot)

train_files_oil_spot = data_from_index(train_files_oil_spot_i, txt_files_oil_spot) + data_from_index(train_files_oil_spot_i, jpg_files_oil_spot)
test_files_oil_spot = data_from_index(test_files_oil_spot_i, txt_files_oil_spot) + data_from_index(test_files_oil_spot_i, jpg_files_oil_spot)
val_files_oil_spot = data_from_index(val_files_oil_spot_i, txt_files_oil_spot) + data_from_index(val_files_oil_spot_i, jpg_files_oil_spot)
len(train_files_oil_spot), len(test_files_oil_spot), len(val_files_oil_spot)
# Out:
# (284, 60, 64)

# %%
indexes_punching_hole = list(range(len(txt_files_punching_hole)))

random.shuffle(indexes_punching_hole)

train_files_punching_hole_i, test_files_punching_hole_i, val_files_punching_hole_i = split_indexes(indexes_punching_hole)

train_files_punching_hole = data_from_index(train_files_punching_hole_i, txt_files_punching_hole) + data_from_index(train_files_punching_hole_i, jpg_files_punching_hole)
test_files_punching_hole = data_from_index(test_files_punching_hole_i, txt_files_punching_hole) + data_from_index(test_files_punching_hole_i, jpg_files_punching_hole)
val_files_punching_hole = data_from_index(val_files_punching_hole_i, txt_files_punching_hole) + data_from_index(val_files_punching_hole_i, jpg_files_punching_hole)
len(train_files_punching_hole), len(test_files_punching_hole), len(val_files_punching_hole)
# Out:
# (300, 64, 66)

# %%
indexes_rolled_pit = list(range(len(txt_files_rolled_pit)))

random.shuffle(indexes_rolled_pit)

train_files_rolled_pit_i, test_files_rolled_pit_i, val_files_rolled_pit_i = split_indexes(indexes_rolled_pit)

train_files_rolled_pit = data_from_index(train_files_rolled_pit_i, txt_files_rolled_pit) + data_from_index(train_files_rolled_pit_i, jpg_files_rolled_pit)
test_files_rolled_pit = data_from_index(test_files_rolled_pit_i, txt_files_rolled_pit) + data_from_index(test_files_rolled_pit_i, jpg_files_rolled_pit)
val_files_rolled_pit = data_from_index(val_files_rolled_pit_i, txt_files_rolled_pit) + data_from_index(val_files_rolled_pit_i, jpg_files_rolled_pit)
len(train_files_rolled_pit), len(test_files_rolled_pit), len(val_files_rolled_pit)
# Out:
# (38, 8, 10)

# %%
indexes_silk_spot = list(range(len(txt_files_silk_spot)))

random.shuffle(indexes_silk_spot)

train_files_silk_spot_i, test_files_silk_spot_i, val_files_silk_spot_i = split_indexes(indexes_silk_spot)

train_files_silk_spot = data_from_index(train_files_silk_spot_i, txt_files_silk_spot) + data_from_index(train_files_silk_spot_i, jpg_files_silk_spot)
test_files_silk_spot = data_from_index(test_files_silk_spot_i, txt_files_silk_spot) + data_from_index(test_files_silk_spot_i, jpg_files_silk_spot)
val_files_silk_spot = data_from_index(val_files_silk_spot_i, txt_files_silk_spot) + data_from_index(val_files_silk_spot_i, jpg_files_silk_spot)
len(train_files_silk_spot), len(test_files_silk_spot), len(val_files_silk_spot)
# Out:
# (908, 194, 196)

# %%
indexes_waist_folding = list(range(len(txt_files_waist_folding)))
print(len(txt_files_waist_folding))
random.shuffle(indexes_waist_folding)

train_files_waist_folding_i, test_files_waist_folding_i, val_files_waist_folding_i = split_indexes(indexes_waist_folding)

train_files_waist_folding = data_from_index(train_files_waist_folding_i, txt_files_waist_folding) + data_from_index(train_files_waist_folding_i, jpg_files_waist_folding)
test_files_waist_folding = data_from_index(test_files_waist_folding_i, txt_files_waist_folding) + data_from_index(test_files_waist_folding_i, jpg_files_waist_folding)
val_files_waist_folding = data_from_index(val_files_waist_folding_i, txt_files_waist_folding) + data_from_index(val_files_waist_folding_i, jpg_files_waist_folding)
len(train_files_waist_folding), len(test_files_waist_folding), len(val_files_waist_folding)
# Out:
# 144
# (200, 42, 46)

# %%
indexes_water_spot = list(range(len(txt_files_water_spot)))

random.shuffle(indexes_water_spot)

train_files_water_spot_i, test_files_water_spot_i, val_files_water_spot_i = split_indexes(indexes_water_spot)

train_files_water_spot = data_from_index(train_files_water_spot_i, txt_files_water_spot) + data_from_index(train_files_water_spot_i, jpg_files_water_spot)
test_files_water_spot = data_from_index(test_files_water_spot_i, txt_files_water_spot) + data_from_index(test_files_water_spot_i, jpg_files_water_spot)
val_files_water_spot = data_from_index(val_files_water_spot_i, txt_files_water_spot) + data_from_index(val_files_water_spot_i, jpg_files_water_spot)
len(train_files_water_spot), len(test_files_water_spot), len(val_files_water_spot)
# Out:
# (400, 86, 88)

# %%
indexes_welding_line = list(range(len(txt_files_welding_line)))

random.shuffle(indexes_welding_line)

train_files_welding_line_i, test_files_welding_line_i, val_files_welding_line_i = split_indexes(indexes_welding_line)

train_files_welding_line = data_from_index(train_files_welding_line_i, txt_files_welding_line) + data_from_index(train_files_welding_line_i, jpg_files_welding_line)
test_files_welding_line = data_from_index(test_files_welding_line_i, txt_files_welding_line) + data_from_index(test_files_welding_line_i, jpg_files_welding_line)
val_files_welding_line = data_from_index(val_files_welding_line_i, txt_files_welding_line) + data_from_index(val_files_welding_line_i, jpg_files_welding_line)
len(train_files_welding_line), len(test_files_welding_line), len(val_files_welding_line)
# Out:
# (372, 80, 82)

# %%
train_files = train_files_crease + train_files_crescent_gap + train_files_inclusion + train_files_oil_spot
train_files += train_files_punching_hole + train_files_rolled_pit + train_files_silk_spot + train_files_waist_folding
train_files += train_files_water_spot + train_files_welding_line

assert len(train_files) == len(train_files_crease) + len(train_files_crescent_gap) + len(train_files_inclusion) + \
len(train_files_oil_spot) + len(train_files_punching_hole) + len(train_files_rolled_pit) + len(train_files_silk_spot) + \
len(train_files_waist_folding) + len(train_files_water_spot) + len(train_files_welding_line)
#print(len(train_files), len(test_files), len(val_files))

# %%
test_files = test_files_crease + test_files_crescent_gap + test_files_inclusion + test_files_oil_spot 
test_files += test_files_punching_hole + test_files_rolled_pit + test_files_silk_spot + test_files_waist_folding
test_files += test_files_water_spot + test_files_welding_line

assert len(test_files) == len(test_files_crease) + len(test_files_crescent_gap) + len(test_files_inclusion) + \
len(test_files_oil_spot) + len(test_files_punching_hole) + len(test_files_rolled_pit) + len(test_files_silk_spot) + \
len(test_files_waist_folding) + len(test_files_water_spot) + len(test_files_welding_line)

# %%
val_files = val_files_crease + val_files_crescent_gap + val_files_inclusion + val_files_oil_spot 
val_files += val_files_punching_hole + val_files_rolled_pit + val_files_silk_spot + val_files_waist_folding
val_files += val_files_water_spot + val_files_welding_line

assert len(val_files) == len(val_files_crease) + len(val_files_crescent_gap) + len(val_files_inclusion) + \
len(val_files_oil_spot) + len(val_files_punching_hole) + len(val_files_rolled_pit) + len(val_files_silk_spot) + \
len(val_files_waist_folding) + len(val_files_water_spot) + len(val_files_welding_line)

# %%
import shutil

def copy_files(files: list, dst: Union[str, Path]):
    dst_path = Path(dst)
    dst_path.mkdir(exist_ok=True)
    
    for file in files:
        shutil.copy(file, dst_path)
    
#source_folder = Path("/kaggle/working/for_data") 
train_folder = Path('/kaggle/working/train')
test_folder = Path('/kaggle/working/test')
valid_folder = Path('/kaggle/working/valid')

shutil.rmtree(train_folder)
shutil.rmtree(test_folder)
shutil.rmtree(valid_folder)


# subfolders = [f.path for f in os.scandir(images_data_folder) if f.is_dir()]
# print(subfolders)
#random.shuffle(subfolders)

copy_files(train_files, train_folder)
copy_files(test_files, test_folder)
copy_files(val_files, valid_folder)

def get_amount_of_files(dir: Path):
    files = [file for file in dir.glob("*")]
    return len(files)

print(get_amount_of_files(train_folder))
print(get_amount_of_files(test_folder))
print(get_amount_of_files(valid_folder))
# Out:
# 3178
# 676
# 706

# %%
text = \
f"""train: {train_folder}
test: {test_folder}
val: {valid_folder}

# Classes 
names:
  0: punching_hole
  1: welding_line
  2: crescent_gap
  3: water_spot
  4: oil_spot
  5: silk_spot
  6: inclusion
  7: rolled_pit
  8: crease
  9: waist folding

"""

print(text.encode())

Path('/kaggle/working/dataset.yaml').write_text(text)
# with open(f'dataset.yaml', 'w') as file:
#     file.write(f'train: /kaggle/working/train\nval: /kaggle/working/valid\ntest: /kaggle/working/test\n# Classes\nnames:\n  0: without_silk_spot\n  1: with_silk_spot\n')
# Out:
# b'train: /kaggle/working/train\ntest: /kaggle/working/test\nval: /kaggle/working/valid\n\n# Classes \nnames:\n  0: punching_hole\n  1: welding_line\n  2: crescent_gap\n  3: water_spot\n  4: oil_spot\n  5: silk_spot\n  6: inclusion\n  7: rolled_pit\n  8: crease\n  9: waist folding\n\n'
# 265

# %%
folder_path = "/kaggle/working"
file_name = "dataset.yaml"

# Получение списка файлов в папке
files = os.listdir(folder_path)

# Поиск файла в списке
if file_name in files:
    print(f"Файл {file_name} найден в папке.")
else:
    print(f"Файл {file_name} не найден в папке.")
# Out:
# Файл dataset.yaml найден в папке.

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.4/40.4 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.4/750.4 kB 15.3 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO
model = YOLO('yolov8x.pt')
# Out:
# ...
# 100%|██████████| 131M/131M [00:00<00:00, 303MB/s]

# %%
model.train(data='/kaggle/working/dataset.yaml', epochs = 100, patience = 20)
# Out:
# Ultralytics YOLOv8.1.46 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# ...
